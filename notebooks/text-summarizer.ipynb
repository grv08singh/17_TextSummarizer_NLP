# %%
# !nvidia-smi
# Out:
# Sat Jun  6 15:31:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.79                 Driver Version: 595.79         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   45C    P8             14W /  115W |     938MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1392    C+G   ....0.3967.54\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            3724    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            5072    C+G   ....0.3967.54\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            9396    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A            9680    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10180    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           10924    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           11252    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           11668    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           11724    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           11732    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12020    C+G   ...cw5n1h2txyewy\WidgetBoard.exe      N/A      |
# |    0   N/A  N/A           13904    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           16420    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           16588    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20644    C+G   ...n1h2txyewy\CHXSmartScreen.exe      N/A      |
# |    0   N/A  N/A           20796    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           22260    C+G   ...rRepo\Notepad++\notepad++.exe      N/A      |
# |    0   N/A  N/A           26136    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           29564    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           32752    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           34360    C+G   ...indows\System32\ShellHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset, load_from_disk
import matplotlib.pyplot as plt
from datasets import load_dataset
import pandas as pd
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm
import torch
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dex\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
model_ckpt = "google/pegasus-cnn_dailymail"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt).to(device)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# c:\Users\Dex\anaconda3\envs\env_textS\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Dex\.cache\huggingface\hub\models--google--pegasus-cnn_dailymail. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 model_ckpt = "google/pegasus-cnn_dailymail"
#       2 tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
# ----> 3 model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt).to(device)
#
# File c:\Users\Dex\anaconda3\envs\env_textS\Lib\site-packages\transformers\models\auto\auto_factory.py:405, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     403         if parent_quant is not None:
#     404             config.quantization_config = parent_quant
# --> 405     return model_class.from_pretrained(
#     406         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     407     )
#     408 raise ValueError(
#     409     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     410     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     411 )
#
# File c:\Users\Dex\anaconda3\envs\env_textS\Lib\site-packages\transformers\modeling_utils.py:4219, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4216 is_quantized = hf_quantizer is not None
#    4218 # Find the correct dtype based on current state
# -> 4219 config, dtype = _get_dtype(
#    4220     dtype, checkpoint_files, config, sharded_metadata, state_dict, weights_only, hf_quantizer
#    4221 )
#    4223 if gguf_file:
#    4224     from .modeling_gguf_pytorch_utils import load_gguf_checkpoint
#
# File c:\Users\Dex\anaconda3\envs\env_textS\Lib\site-packages\transformers\modeling_utils.py:848, in _get_dtype(dtype, checkpoint_files, config, sharded_metadata, state_dict, weights_only, hf_quantizer)
#     846     dtype = torch.float32
#     847 else:
# --> 848     state_dict = load_state_dict(
#     849         checkpoint_files[0], map_location="meta", weights_only=weights_only
#     850     )
#     851     dtype = get_state_dict_dtype(state_dict)
#     852 logger.info(
#     853     f"Since the `dtype` attribute can't be found in model's config object, "
#     854     f"will use dtype={dtype} as derived from model's weights"
#     855 )
#
# File c:\Users\Dex\anaconda3\envs\env_textS\Lib\site-packages\transformers\modeling_utils.py:374, in load_state_dict(checkpoint_file, map_location, weights_only, disable_mmap)
#     372 # Fallback to torch.load (if weights_only was explicitly False, do not check safety as this is known to be unsafe)
#     373 if weights_only:
# --> 374     check_torch_load_is_safe()
#     375 extra_args = {}
#     376 # mmap can only be used with files serialized with zipfile-based format.
#
# File c:\Users\Dex\anaconda3\envs\env_textS\Lib\site-packages\transformers\utils\import_utils.py:1384, in check_torch_load_is_safe()
#    1382 def check_torch_load_is_safe() -> None:
#    1383     if not is_torch_greater_or_equal("2.6"):
# -> 1384         raise ValueError(
#    1385             "Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users "
#    1386             "to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply "
#    1387             "when loading files with safetensors."
#    1388             "\nSee the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434"
#    1389         )
#
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
